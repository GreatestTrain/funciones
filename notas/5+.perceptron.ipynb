# %% [markdown]
# ## Perceptrón
# -------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Función Lineal
# (Es una función de activación)

# %%
def f(x):
    return x
x = np.linspace(-10,10,1000) 
y = f(x)
plt.plot(x, y)
plt.grid()

# %% [markdown]
# #### Función segmentada
# $$
#     f(x) =
#     \begin{cases}
#     0,&\quad\text{para } x<0\\
#     1,&\quad\text{para } x\ge0\\
#     \end{cases}
# $$

# %%
def H(x):
    y = np.zeros_like(x)
    for i, v in enumerate(x):
        if v < 0:
            y[i] = 0
        elif v >= 0:
            y[i] = 1
    return y

x = np.linspace(-10,10,1000) 
y = H(x)
plt.plot(x, y)
plt.grid()

# %% [markdown]
# #### Función Sigmoide
# $$f(x) = \frac{1}{1-e^{-x}}$$

# %%
def f(x):
    return 1/(1+np.exp(-x))
y = f(x) 
plt.plot(x, y)
plt.grid()

# %% [markdown]
# #### Función tangente hipérbolica
# $$ f(x) = \frac{2}{1+e^{-2x}} - 1$$

# %%
# def f(x):
    # return 2/(1+np.exp(-2*x)) - 1 
def f(x):
    return np.tanh(x)


y = f(x)

plt.plot(x, y)
plt.grid()

# %% [markdown]
# #### Función ReLU
# $$ R(x) = max(0,x) $$

# %%
def f(x):
    return np.maximum(0, x)

y = f(x)
plt.plot(x, y)
plt.grid()
